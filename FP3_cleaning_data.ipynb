# %% [markdown]
# <center> <h1> DS 3000 </h1> </center>
# <center> <h1> Final Project - Cleaning Dataset </h1> </center>

# %% [markdown]
# <center> <h3> Group 17: Deo Gracias Ong, Gyuwon Lee, Ashwin Rupakula </h3></center>

# %% [markdown]
# # Importing and reading the dataset from Github link

# %%
import pandas as pd
data = pd.read_csv("https://raw.githubusercontent.com/GioOng/DS3000_finalProject/main/bank-full.csv", delimiter=';')
data
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %% [markdown]
# # Creating a dictionary with the appropriate numerical replacement for each string value

# %%
name_rep_dict = {'unknown': 0, 'management': 1, 'technician': 2, 'entrepreneur': 3, 'blue-collar': 4, 'retired': 5,
                'admin.': 6, 'servies': 7, 'self-employed': 8, 'unemployed': 9, 'housemaid': 10, 'student': 11,
                'single': 0, 'married': 1, 'divorced': 2, 'primary': 1, 'secondary': 2, 'tertiary': 3, 'no': 0, 'yes': 1,
                'jan': 1, 'feb': 2, 'mar': 3, 'apr': 4, 'may': 5, 'jun': 6, 'jul': 7, 'aug': 8, 'sep': 9, 'oct': 10,
                'nov': 11, 'dec':12, 'success': 1, 'failure': 2,  'other': 3}

# %% [markdown]
# # Replacing all string categorical values into their corresponding numerical values

# %%
data = data.drop(columns=['day', 'contact'])
data.replace(name_rep_dict, inplace=True)
data
# Out:
#        age job  marital  education  default  balance  housing  loan  month  \
# 0       58   1        1          3        0     2143        1     0      5
# 1       44   2        0          2        0       29        1     0      5
# 2       33   3        1          2        0        2        1     1      5
# 3       47   4        1          0        0     1506        1     0      5
# 4       33   0        0          0        0        1        0     0      5
# ...    ...  ..      ...        ...      ...      ...      ...   ...    ...
# 45206   51   2        1          3        0      825        0     0     11
# 45207   71   5        2          1        0     1729        0     0     11
# 45208   72   5        1          2        0     5715        0     0     11
# 45209   57   4        1          2        0      668        0     0     11
# 45210   37   3        1          2        0     2971        0     0     11
#
#        duration  campaign  pdays  previous  poutcome  y
# ...

# %%
# string_columns = ['job','marital','education','housing','loan','month','poutcome','y']
# for name in string_columns:
#     unq_vals = data[str(name)].unique()
#     print(unq_vals)
#     for i in range(len(unq_vals)):
#         data = data.replace(str(unq_vals[i]),int(i))
